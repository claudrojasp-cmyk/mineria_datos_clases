# %% [markdown]
# <a href="https://colab.research.google.com/github/claudrojasp-cmyk/mineria_datos_clases/blob/main/mineriaDatosTarea.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importar las librerias
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 1000)

# %%
# leer el dataframe
df = pd.read_csv("/content/LeMansWinners.csv")

# %%
#mostrar las 5 primeras filas
df.head()
# Out:
#    Year               Drivers Class                                 Team  \
# 0  1923         André Lagache   3.0                 Chenard & Walcker SA
# 1  1923          René Léonard   3.0                 Chenard & Walcker SA
# 2  1924         Frank Clement   3.0                     Duff & Aldington
# 3  1924             John Duff   3.0                     Duff & Aldington
# 4  1925  Gérard de Courcelles   5.0  Société Lorraine De Dietrich et Cie
#
#                                   Car       Tyre   Laps        Km        Mi  \
# 0  Chenard-Walcker Type U3 15CV Sport   Michelin  128.0  2209.536  1372.942
# 1  Chenard-Walcker Type U3 15CV Sport   Michelin  128.0  2209.536  1372.942
# 2               Bentley 3 Litre Sport     Rapson  120.0  2077.340  1290.800
# 3               Bentley 3 Litre Sport     Rapson  120.0  2077.340  1290.800
# 4        Lorraine-Dietrich B3-6 Sport  Englebert  129.0  2233.982  1388.132
#
# ...

# %%
#mostrar las columnas de mi dataset
df.columns
# Out:
# Index(['Year', 'Drivers', 'Class', 'Team', 'Car', 'Tyre', 'Laps', 'Km', 'Mi',
#        'Series', 'Driver_nationality', 'Team_nationality', 'Average_speed_kmh',
#        'Average_speed_mph', 'Average_lap_time'],
#       dtype='object')

# %%
df['Class'].mode()
# Out:
# 0    Le Mans Prototype
# Name: Class, dtype: object

# %%
#muestra cantidad (filas/columnas)
df.shape
# Out:
# (227, 15)

# %%
"""
Cuando identifiquemos columnas categóricas, debemos observar la
cantidad de categóricas en dicha columna
"""

# df['nombre_col_cat'].value_counts() #mostrará las categorias y distribuciones
# df['nombre_col_cat'].value_counts().count() #mostrará el numero
# Out:
# '\nCuando identifiquemos columnas categóricas, debemos observar la\ncantidad de categóricas en dicha columna\n'

# %%
#estadísticas en varibales numéricas
df.describe().round()
# Out:
#          Year   Laps      Km      Mi  Average_speed_kmh  Average_speed_mph  \
# count   227.0  227.0   227.0   227.0              227.0              227.0
# mean   1981.0  330.0  4525.0  2812.0              189.0              117.0
# std      28.0   68.0   826.0   514.0               34.0               21.0
# min    1923.0  120.0  2077.0  1291.0               87.0               54.0
# 25%    1961.0  314.0  4218.0  2621.0              176.0              109.0
# 50%    1986.0  355.0  4814.0  2992.0              201.0              125.0
# 75%    2004.0  375.0  5100.0  3181.0              212.0              133.0
# max    2023.0  397.0  5411.0  3362.0              225.0              140.0
#
#        Average_lap_time
# count             227.0
# mean                5.0
# std                 2.0
# min                 4.0
# 25%                 4.0
# 50%                 4.0
# 75%                 5.0
# max                12.0

# %%
df.info() #mostrara tipos de datos y nulos en el dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                227 non-null    int64
#  1   Drivers             227 non-null    object
#  2   Class               227 non-null    object
#  3   Team                227 non-null    object
#  4   Car                 227 non-null    object
#  5   Tyre                227 non-null    object
#  6   Laps                227 non-null    float64
#  7   Km                  227 non-null    float64
#  8   Mi                  227 non-null    float64
#  9   Series              227 non-null    object
#  10  Driver_nationality  227 non-null    object
#  11  Team_nationality    227 non-null    object
#  12  Average_speed_kmh   227 non-null    float64
#  13  Average_speed_mph   227 non-null    float64
#  14  Average_lap_time    227 non-null    float64
# ...

# %%
df.isnull().sum() #mostrara la cantidad de nulos por columna
# Out:
# Year                  0
# Drivers               0
# Class                 0
# Team                  0
# Car                   0
# Tyre                  0
# Laps                  0
# Km                    0
# Mi                    0
# Series                0
# Driver_nationality    0
# Team_nationality      0
# Average_speed_kmh     0
# Average_speed_mph     0
# Average_lap_time      0
# dtype: int64

# %%
df_limpio = df.dropna() #borramos nulos (no aplicar aun)

# %%
df_limpio.to_csv("nuevo_csv_limpio.csv")

# %%
df['Series'].hist()
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#variable/ dataframe/ seleccionames los tipo number/ obtenemos la correlacion de pearson
corr = df.select_dtypes(include='number').corr()
#corr_ejem2 = df.corr()

sns.heatmap(corr, annot= True, cmap="coolwarm")

plt.title("Mapa de calor de correlación")
plt.show()

# %% [markdown]
# Prueba de códigos

# %%
df.isnull().any().any()
# Out:
# np.False_

# %%
df.shape
# Out:
# (227, 15)

# %%
df.dtypes
# Out:
# Year                    int64
# Drivers                object
# Class                  object
# Team                   object
# Car                    object
# Tyre                   object
# Laps                  float64
# Km                    float64
# Mi                    float64
# Series                 object
# Driver_nationality     object
# Team_nationality       object
# Average_speed_kmh     float64
# Average_speed_mph     float64
# Average_lap_time      float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Year', 'Drivers', 'Class', 'Team', 'Car', 'Tyre', 'Laps', 'Km', 'Mi',
#        'Series', 'Driver_nationality', 'Team_nationality', 'Average_speed_kmh',
#        'Average_speed_mph', 'Average_lap_time'],
#       dtype='object')

# %%
cant_cat_col_driver_df = df['Drivers'].value_counts()# nos mostrará la cantidad de categoricas distintas unicas de los pilotos que ganaron en Le Mans
print(cant_cat_col_driver_df)

# Imprimimos la cantidad total de categorias unicas
print(f"cantidad pilotos: {cant_cat_col_driver_df.count()}")
# Out:
# Drivers
# Tom Kristensen            9
# Jacky Ickx                6
# Derek Bell                5
# Henri Pescarolo           5
# Frank Biela               5
# Emanuele Pirro            5
# Yannick Dalmas            4
# Olivier Gendebien         4
# Sébastien Buemi           4
# Luigi Chinetti            3
# Woolf Barnato             3
# Allan McNish              3
# Rinaldo Capello           3
# Benoît Tréluyer           3
# Hurley Haywood            3
# Brendon Hartley           3
# Marcel Fässler            3
# André Lotterer            3
# Kazuki Nakajima           3
# Marco Werner              3
# Phil Hill                 3
# Al Holbert                3
# Klaus Ludwig              3
# Jackie Oliver             2
# Gérard Larrousse          2
# Raymond Sommer            2
# Henry Birkin              2
# André Rossignol           2
# Hans-Joachim Stuck        2
# JJ Lehto                  2
# Alexander Wurz            2
# Earl Bamber               2
# Timo Bernhard             2
# ...

# %%
df.describe()
# Out:
#               Year        Laps           Km           Mi  Average_speed_kmh  \
# count   227.000000  227.000000   227.000000   227.000000         227.000000
# mean   1980.986784  330.444934  4524.541837  2811.835260         188.522731
# std      28.368230   67.916531   826.414489   513.810879          34.434276
# min    1923.000000  120.000000  2077.340000  1290.800000          86.560000
# 25%    1961.000000  314.000000  4217.527000  2620.650000         175.730000
# 50%    1986.000000  355.000000  4814.400000  2991.500000         200.600000
# 75%    2004.500000  375.000000  5100.000000  3180.640000         212.500000
# max    2023.000000  397.000000  5410.713000  3362.061000         225.450000
#
#        Average_speed_mph  Average_lap_time
# count         227.000000        227.000000
# mean          117.159692          4.687930
# std            21.408283          1.689974
# min            53.780000          3.630000
# 25%           109.190000          3.840000
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# Le Mans Prototype        72
# Group C                  34
# S Group 5 (racing)       18
# 5.0                      16
# S 5.0                    14
# 3.0                      10
# S 3.0                    10
# Group GT1                 9
# Hypercar                  9
# P Group 3 (racing)        7
# Gp.6 Group 6 (racing)     7
# 8.0                       4
# S Group 6 (racing)        4
# P Group 4 (racing)        4
# Gp.5 Group 5 (racing)     3
# E +3.0                    2
# >3.0                      2
# S 2.0                     2
# Name: count, dtype: int64

# %%
df
# Out:
#      Year                 Drivers                  Class  \
# 0    1923           André Lagache                    3.0
# 1    1923            René Léonard                    3.0
# 2    1924           Frank Clement                    3.0
# 3    1924               John Duff                    3.0
# 4    1925    Gérard de Courcelles                    5.0
# 5    1925         André Rossignol                    5.0
# 6    1926            Robert Bloch                    5.0
# 7    1926         André Rossignol                    5.0
# 8    1927       Dudley Benjafield                    3.0
# 9    1927             Sammy Davis                    3.0
# 10   1928           Woolf Barnato                    5.0
# 11   1928           Bernard Rubin                    5.0
# 12   1929           Woolf Barnato                    8.0
# 13   1929            Henry Birkin                    8.0
# 14   1930           Woolf Barnato                   >3.0
# ...
